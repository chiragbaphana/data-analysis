# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/12/2000', periods=10),columns=list('ABCD'))
print(df)
df.plot()
# Out:
#                    A         B         C         D
# 2000-01-12  0.933808 -0.623687  1.205940 -2.121546
# 2000-01-13 -0.542382 -1.352032  0.445750 -0.318225
# 2000-01-14 -2.285888  1.058398  0.174942 -0.581127
# 2000-01-15  0.032696 -0.659911 -0.260165  0.606716
# 2000-01-16 -0.245014  0.278790 -0.416631  1.477134
# 2000-01-17 -0.257132 -2.074979 -0.532460 -1.529659
# 2000-01-18  0.851233  0.688688 -0.460306 -0.351820
# 2000-01-19 -0.461549 -0.328046 -0.884407  0.263426
# 2000-01-20  0.687699  1.122003 -1.193457  1.043394
# 2000-01-21 -0.010352  0.925021  2.051868 -1.160797

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),
                index=pd.date_range('1/12/2000', periods=10),
                columns=list(['A','B']))

print(df)
df.plot()
# Out:
#                    A         B
# 2000-01-12  1.181654 -0.154355
# 2000-01-13 -0.017297  0.666828
# 2000-01-14  0.267482 -0.680736
# 2000-01-15  0.073083  0.936282
# 2000-01-16 -0.074415 -0.852158
# 2000-01-17  0.063505  0.961235
# 2000-01-18  0.076399 -0.531874
# 2000-01-19  0.675313 -1.843991
# 2000-01-20 -0.916021 -0.115919
# 2000-01-21  1.256638  0.691311

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=list('ABCD'))
print(df)
df.plot.bar()
# Out:
#           A         B         C         D
# 0  0.628621  0.702272  0.587860  0.495431
# 1  0.938747  0.697452  0.595794  0.902312
# 2  0.280693  0.230069  0.812545  0.835836
# 3  0.810708  0.795133  0.247750  0.504048
# 4  0.627482  0.087688  0.319914  0.973157
# 5  0.321372  0.895253  0.023303  0.690068
# 6  0.143890  0.857383  0.274926  0.708825
# 7  0.882387  0.267322  0.062259  0.525714
# 8  0.250703  0.181693  0.309878  0.717403
# 9  0.211522  0.451596  0.525358  0.857201

# %%
  import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.bar(stacked=True)
# Out:
#           a         b         c         d
# 0  0.302109  0.426031  0.603453  0.500083
# 1  0.316563  0.613647  0.228855  0.883674
# 2  0.442697  0.525492  0.871525  0.146319
# 3  0.641852  0.202614  0.131912  0.156793
# 4  0.433112  0.447308  0.402885  0.201745
# 5  0.195712  0.375063  0.684190  0.127991
# 6  0.334772  0.434005  0.516701  0.226105
# 7  0.690077  0.090922  0.006232  0.855988
# 8  0.327590  0.654337  0.137772  0.962996
# 9  0.952623  0.623376  0.764235  0.733410

# %%
  import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.barh(stacked=True)
# Out:
#           a         b         c         d
# 0  0.270212  0.615653  0.518302  0.934964
# 1  0.147512  0.523120  0.860528  0.257598
# 2  0.165815  0.464306  0.889910  0.335106
# 3  0.694935  0.210906  0.739817  0.821108
# 4  0.099350  0.228759  0.178808  0.245666
# 5  0.579493  0.362592  0.047425  0.454871
# 6  0.279972  0.783812  0.624323  0.416986
# 7  0.525446  0.065524  0.546530  0.025861
# 8  0.798850  0.985934  0.887265  0.715177
# 9  0.957325  0.349523  0.022922  0.639244

# %%
df=pd.DataFrame({'a':np.random.rand(1000)+1,'b':np.random.rand(1000),'c':np.random.randn(1000)-1},columns=['a','b','c'])
print(df)
df.plot.hist(bins=30)
# Out:
#             a         b         c
# 0    1.101253  0.783831 -0.772743
# 1    1.750777  0.736184  0.521882
# 2    1.590936  0.401877 -2.885894
# 3    1.721238  0.341063 -1.323483
# 4    1.835739  0.947842 -1.653145
# 5    1.910736  0.969520 -1.024921
# 6    1.188122  0.559211 -0.559544
# 7    1.489258  0.010030 -1.589985
# 8    1.858857  0.850754 -0.114437
# 9    1.315558  0.128078  0.551921
# 10   1.185104  0.264497 -0.056001
# 11   1.806427  0.328917 -1.017123
# 12   1.123864  0.971811 -1.556986
# 13   1.077130  0.912412 -2.752917
# 14   1.926724  0.406932 -0.497973
# 15   1.267100  0.260792 -1.825688
# 16   1.795280  0.390816 -0.834194
# 17   1.825434  0.091731 -0.946170
# 18   1.374633  0.110075 -0.950277
# 19   1.049284  0.070849 -1.067372
# 20   1.881342  0.941885 -0.474982
# 21   1.756152  0.114760 -0.724383
# 22   1.499880  0.321493 -1.110067
# 23   1.571714  0.589992 -2.280776
# 24   1.972856  0.553823 -0.051032
# 25   1.928756  0.770211 -1.068854
# ...

# %%
df=pd.DataFrame({'a':np.random.rand(1000)+1,'b':np.random.rand(1000),'c':np.random.randn(1000)-1},columns=['a','b','c'])
print(df)
df.plot.box()
# Out:
#             a         b         c
# 0    1.599145  0.918588 -2.163675
# 1    1.285289  0.334334 -0.883053
# 2    1.409926  0.096799  0.475996
# 3    1.236282  0.665308 -1.585777
# 4    1.363170  0.345630 -0.490221
# 5    1.837465  0.694149  0.192516
# 6    1.500968  0.721998 -1.495938
# 7    1.235892  0.456928 -0.984107
# 8    1.872756  0.112846 -0.301403
# 9    1.922886  0.448095 -1.985365
# 10   1.057290  0.342400 -1.493025
# 11   1.223458  0.760455 -2.635357
# 12   1.780221  0.877480 -0.760075
# 13   1.608188  0.321877 -0.614081
# 14   1.900815  0.780322 -1.948644
# 15   1.256102  0.554271 -3.202660
# 16   1.849521  0.406875 -0.557112
# 17   1.924255  0.503624 -1.265774
# 18   1.599298  0.672448 -1.486236
# 19   1.872084  0.180872 -0.411079
# 20   1.397357  0.144311 -2.165100
# 21   1.750556  0.644561 -1.185712
# 22   1.992233  0.930681 -2.312656
# 23   1.861431  0.422216  0.814201
# 24   1.941106  0.262493  0.099263
# 25   1.720023  0.547590 -0.762284
# ...

# %%
df=pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
print(df)
df.plot.area()
# Out:
#           a         b         c         d
# 0  0.408695  0.540031  0.916554  0.762659
# 1  0.069090  0.738833  0.623411  0.598869
# 2  0.415476  0.318795  0.595603  0.707368
# 3  0.279520  0.176703  0.636639  0.047770
# 4  0.611388  0.631453  0.510607  0.386316
# 5  0.305522  0.307405  0.798403  0.246684
# 6  0.923860  0.050406  0.644062  0.090158
# 7  0.792467  0.466866  0.198624  0.748643
# 8  0.728161  0.788484  0.315223  0.516815
# 9  0.817084  0.150615  0.932921  0.927642

# %%
df=pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
print(df)
df.plot.scatter(x='a',y='b')
# Out:
#            a         b         c         d
# 0   0.078913  0.680910  0.542555  0.055451
# 1   0.926761  0.502578  0.152247  0.929527
# 2   0.260964  0.206194  0.480832  0.794357
# 3   0.467496  0.709501  0.686927  0.231260
# 4   0.944056  0.296138  0.364640  0.060909
# 5   0.002183  0.638423  0.538175  0.064550
# 6   0.909692  0.179904  0.264232  0.823152
# 7   0.979783  0.485172  0.860576  0.914841
# 8   0.602582  0.776360  0.062348  0.022196
# 9   0.655724  0.656130  0.968269  0.128078
# 10  0.890662  0.695934  0.774823  0.107581
# 11  0.436561  0.139684  0.838647  0.646318
# 12  0.959024  0.330501  0.397477  0.673743
# 13  0.084577  0.192030  0.496259  0.666480
# 14  0.287338  0.974613  0.451284  0.780060
# 15  0.068487  0.211198  0.709953  0.881272
# 16  0.334175  0.664991  0.729562  0.650227
# 17  0.184727  0.807852  0.487288  0.989857
# 18  0.551850  0.314891  0.414161  0.897332
# 19  0.265586  0.185711  0.235707  0.303771
# 20  0.623291  0.801602  0.315113  0.550746
# ...

# %%
df=pd.DataFrame(3*np.random.rand(4),index=['a','b','c','d'],columns=['x'])
print(df)
df.plot.pie(subplots=True)
# Out:
#           x
# a  2.821590
# b  1.610261
# c  1.058606
# d  0.140676
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000022F40A72438>],
#       dtype=object)
